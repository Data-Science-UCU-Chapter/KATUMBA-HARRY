# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('gapminder2.csv')
df
# Out:
#         country continent  year  lifeExp       pop    gdpPercap
# 0   Afghanistan      Asia  1952   28.901   8425333   779.445314
# 1   Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2   Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3   Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4   Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5   Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6   Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7   Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8   Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9   Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10  Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11  Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12      Albania    Europe  1952   55.230   1282697  1601.056136
# 13      Albania    Europe  1957   59.280   1476505  1942.284244
# 14      Albania    Europe  1962   64.820   1728137  2312.888958
# 15      Albania    Europe  1967   66.220   1984060  2760.196931
# 16      Albania    Europe  1972   67.690   2263554  3313.422188
# 17      Albania    Europe  1977   68.930   2509048  3533.003910
# 18      Albania    Europe  1982   70.420   2780097  3630.880722
# 19      Albania    Europe  1987   72.000   3075321  3738.932735
# 20      Albania    Europe  1992   71.581   3326498  2497.437901
# 21      Albania    Europe  1997   72.950   3428038  3193.054604
# 22      Albania    Europe  2002   75.651   3508512  4604.211737
# 23      Albania    Europe  2007   76.423   3600523  5937.029526
# 24      Algeria    Africa  1952   43.077   9279525  2449.008185
# 25      Algeria    Africa  1957   45.685  10270856  3013.976023
# 26      Algeria    Africa  1962   48.303  11000948  2550.816880
# 27      Algeria    Africa  1967   51.407  12760499  3246.991771
# 28      Algeria    Africa  1972   54.518  14760787  4182.663766
# 29      Algeria    Africa  1977   58.014  17152804  4910.416756
# 30      Bolivia  Americas  1952   40.414   2883315  2677.326347
# 31      Bolivia  Americas  1957   41.890   3211738  2127.686326
# 32      Bolivia  Americas  1962   43.428   3593918  2180.972546
# 33      Bolivia  Americas  1967   45.032   4040665  2586.886053
# 34      Bolivia  Americas  1972   46.714   4565872  2980.331339
# 35      Bolivia  Americas  1977   50.023   5079716  3548.097832
# 36      Bolivia  Americas  1982   53.859   5642224  3156.510452
# 37      Bolivia  Americas  1987   57.251   6156369  2753.691490
# 38      Bolivia  Americas  1992   59.957   6893451  2961.699694
# 39      Bolivia  Americas  1997   62.050   7693188   326.143191
# 40      Bolivia  Americas  2002   63.883   8445134  3413.262690
# 41      Bolivia  Americas  2007   65.554   9119152  3822.137084

# %%
df.head()       #prints the first 5 rowas of the data set
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.901   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.shape    #prints the number of rows and columns
# Out:
# (42, 6)

# %%
df.columns      #prints the number of columns in data set
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.dtypes        #prints the data
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
df.info        #prints more information about the columns
# Out:
# <bound method DataFrame.info of         country continent  year  lifeExp       pop    gdpPercap
# 0   Afghanistan      Asia  1952   28.901   8425333   779.445314
# 1   Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2   Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3   Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4   Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5   Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6   Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7   Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8   Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9   Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10  Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11  Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12      Albania    Europe  1952   55.230   1282697  1601.056136
# 13      Albania    Europe  1957   59.280   1476505  1942.284244
# 14      Albania    Europe  1962   64.820   1728137  2312.888958
# 15      Albania    Europe  1967   66.220   1984060  2760.196931
# 16      Albania    Europe  1972   67.690   2263554  3313.422188
# 17      Albania    Europe  1977   68.930   2509048  3533.003910
# 18      Albania    Europe  1982   70.420   2780097  3630.880722
# 19      Albania    Europe  1987   72.000   3075321  3738.932735
# 20      Albania    Europe  1992   71.581   3326498  2497.437901
# 21      Albania    Europe  1997   72.950   3428038  3193.054604
# 22      Albania    Europe  2002   75.651   3508512  4604.211737
# 23      Albania    Europe  2007   76.423   3600523  5937.029526
# 24      Algeria    Africa  1952   43.077   9279525  2449.008185
# 25      Algeria    Africa  1957   45.685  10270856  3013.976023
# 26      Algeria    Africa  1962   48.303  11000948  2550.816880
# 27      Algeria    Africa  1967   51.407  12760499  3246.991771
# 28      Algeria    Africa  1972   54.518  14760787  4182.663766
# 29      Algeria    Africa  1977   58.014  17152804  4910.416756
# 30      Bolivia  Americas  1952   40.414   2883315  2677.326347
# 31      Bolivia  Americas  1957   41.890   3211738  2127.686326
# 32      Bolivia  Americas  1962   43.428   3593918  2180.972546
# 33      Bolivia  Americas  1967   45.032   4040665  2586.886053
# 34      Bolivia  Americas  1972   46.714   4565872  2980.331339
# 35      Bolivia  Americas  1977   50.023   5079716  3548.097832
# 36      Bolivia  Americas  1982   53.859   5642224  3156.510452
# 37      Bolivia  Americas  1987   57.251   6156369  2753.691490
# 38      Bolivia  Americas  1992   59.957   6893451  2961.699694
# 39      Bolivia  Americas  1997   62.050   7693188   326.143191
# 40      Bolivia  Americas  2002   63.883   8445134  3413.262690
# 41      Bolivia  Americas  2007   65.554   9119152  3822.137084>

# %% [markdown]
# Accessing the different rows and columns

# %%
country = df['country']                            #prints the column country
country
# Out:
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# 5     Afghanistan
# 6     Afghanistan
# 7     Afghanistan
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# 12        Albania
# 13        Albania
# 14        Albania
# 15        Albania
# 16        Albania
# 17        Albania
# 18        Albania
# 19        Albania
# 20        Albania
# 21        Albania
# 22        Albania
# 23        Albania
# 24        Algeria
# 25        Algeria
# 26        Algeria
# 27        Algeria
# 28        Algeria
# 29        Algeria
# 30        Bolivia
# 31        Bolivia
# 32        Bolivia
# 33        Bolivia
# 34        Bolivia
# 35        Bolivia
# 36        Bolivia
# 37        Bolivia
# 38        Bolivia
# 39        Bolivia
# 40        Bolivia
# 41        Bolivia
# Name: country, dtype: object

# %%
df['country'].head(5)                                #prints the first 5 countries
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
df['country'].tail()                                 #prints the last 5 countries
# Out:
# 37    Bolivia
# 38    Bolivia
# 39    Bolivia
# 40    Bolivia
# 41    Bolivia
# Name: country, dtype: object

# %%
subset = df[['country','year','continent']]
subset.head()
# Out:
#        country  year continent
# 0  Afghanistan  1952      Asia
# 1  Afghanistan  1957      Asia
# 2  Afghanistan  1962      Asia
# 3  Afghanistan  1967      Asia
# 4  Afghanistan  1972      Asia

# %%
subset.tail()
# Out:
#     country  year continent
# 37  Bolivia  1987  Americas
# 38  Bolivia  1992  Americas
# 39  Bolivia  1997  Americas
# 40  Bolivia  2002  Americas
# 41  Bolivia  2007  Americas

# %% [markdown]
# Accessing rows

# %%
df.loc[0]                                   #prints the first row of data set
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.901
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.tail(n=1)                                  #prints the last row of data set
# Out:
#     country continent  year  lifeExp      pop    gdpPercap
# 41  Bolivia  Americas  2007   65.554  9119152  3822.137084

# %%
#Accessing different rows at the same time
df.loc[[1,23,34]]
# Out:
#         country continent  year  lifeExp      pop    gdpPercap
# 1   Afghanistan      Asia  1957   30.332  9240934   820.853030
# 23      Albania    Europe  2007   76.423  3600523  5937.029526
# 34      Bolivia  Americas  1972   46.714  4565872  2980.331339

# %% [markdown]
# Accessing columns
#
#
# using the loc[] keyword, note the position of the colon

# %%
cols = df.loc[:,['country','year']]
cols.head(6)
# Out:
#        country  year
# 0  Afghanistan  1952
# 1  Afghanistan  1957
# 2  Afghanistan  1962
# 3  Afghanistan  1967
# 4  Afghanistan  1972
# 5  Afghanistan  1977

# %%
range1 = list(range(5))
range1
# Out:
# [0, 1, 2, 3, 4]

# %%
cols1=df.iloc[:,range1]
cols1.tail()
# Out:
#     country continent  year  lifeExp      pop
# 37  Bolivia  Americas  1987   57.251  6156369
# 38  Bolivia  Americas  1992   59.957  6893451
# 39  Bolivia  Americas  1997   62.050  7693188
# 40  Bolivia  Americas  2002   63.883  8445134
# 41  Bolivia  Americas  2007   65.554  9119152

# %%
#Accessing both rows and columns simultaneously
df.loc[23,'pop']
# Out:
# 3600523

# %%
df.iloc[[0,9,39],[0,3,5]]
# Out:
#         country  lifeExp   gdpPercap
# 0   Afghanistan   28.901  779.445314
# 9   Afghanistan   41.763  635.341351
# 39      Bolivia   62.050  326.143191

# %%
df.loc[[0,9,39],['country','year','pop']]
# Out:
#         country  year       pop
# 0   Afghanistan  1952   8425333
# 9   Afghanistan  1997  22227415
# 39      Bolivia  1997   7693188

# %%
df.loc[10:13,['country','lifeExp','gdpPercap']]
# Out:
#         country  lifeExp    gdpPercap
# 10  Afghanistan   42.129   726.734055
# 11  Afghanistan   43.828   974.580338
# 12      Albania   55.230  1601.056136
# 13      Albania   59.280  1942.284244

# %% [markdown]
# Grouping data using the mean

# %%
group1 = df.groupby('year')['lifeExp'].mean()
group1
# Out:
# year
# 1952    41.905500
# 1957    44.296750
# 1962    47.137000
# 1967    49.169750
# 1972    51.252500
# 1977    53.851250
# 1982    54.711000
# 1987    56.691000
# 1992    57.737333
# 1997    58.921000
# 2002    60.554333
# 2007    61.935000
# Name: lifeExp, dtype: float64

# %%
group2 = df.groupby(['year','continent'])[['lifeExp','gdpPercap']].mean()
group2
# Out:
#                 lifeExp    gdpPercap
# year continent
# 1952 Africa      43.077  2449.008185
#      Americas    40.414  2677.326347
#      Asia        28.901   779.445314
#      Europe      55.230  1601.056136
# 1957 Africa      45.685  3013.976023
#      Americas    41.890  2127.686326
#      Asia        30.332   820.853030
#      Europe      59.280  1942.284244
# 1962 Africa      48.303  2550.816880
#      Americas    43.428  2180.972546
#      Asia        31.997   853.100710
#      Europe      64.820  2312.888958
# 1967 Africa      51.407  3246.991771
#      Americas    45.032  2586.886053
#      Asia        34.020   836.197138
#      Europe      66.220  2760.196931
# 1972 Africa      54.518  4182.663766
#      Americas    46.714  2980.331339
#      Asia        36.088   739.981106
#      Europe      67.690  3313.422188
# 1977 Africa      58.014  4910.416756
#      Americas    50.023  3548.097832
#      Asia        38.438   786.113360
#      Europe      68.930  3533.003910
# 1982 Americas    53.859  3156.510452
#      Asia        39.854   978.011439
#      Europe      70.420  3630.880722
# 1987 Americas    57.251  2753.691490
#      Asia        40.822   852.395945
#      Europe      72.000  3738.932735
# 1992 Americas    59.957  2961.699694
#      Asia        41.674   649.341395
#      Europe      71.581  2497.437901
# 1997 Americas    62.050   326.143191
#      Asia        41.763   635.341351
#      Europe      72.950  3193.054604
# 2002 Americas    63.883  3413.262690
#      Asia        42.129   726.734055
#      Europe      75.651  4604.211737
# 2007 Americas    65.554  3822.137084
#      Asia        43.828   974.580338
#      Europe      76.423  5937.029526

# %%
group2 = df.groupby(['year','continent'])[['lifeExp','gdpPercap']].mean()
group2.head(15)
# Out:
#                 lifeExp    gdpPercap
# year continent
# 1952 Africa      43.077  2449.008185
#      Americas    40.414  2677.326347
#      Asia        28.901   779.445314
#      Europe      55.230  1601.056136
# 1957 Africa      45.685  3013.976023
#      Americas    41.890  2127.686326
#      Asia        30.332   820.853030
#      Europe      59.280  1942.284244
# 1962 Africa      48.303  2550.816880
#      Americas    43.428  2180.972546
#      Asia        31.997   853.100710
#      Europe      64.820  2312.888958
# 1967 Africa      51.407  3246.991771
#      Americas    45.032  2586.886053
#      Asia        34.020   836.197138

# %%
flat = group2.reset_index()                 
flat.head(15)
# Out:
#     year continent  lifeExp    gdpPercap
# 0   1952    Africa   43.077  2449.008185
# 1   1952  Americas   40.414  2677.326347
# 2   1952      Asia   28.901   779.445314
# 3   1952    Europe   55.230  1601.056136
# 4   1957    Africa   45.685  3013.976023
# 5   1957  Americas   41.890  2127.686326
# 6   1957      Asia   30.332   820.853030
# 7   1957    Europe   59.280  1942.284244
# 8   1962    Africa   48.303  2550.816880
# 9   1962  Americas   43.428  2180.972546
# 10  1962      Asia   31.997   853.100710
# 11  1962    Europe   64.820  2312.888958
# 12  1967    Africa   51.407  3246.991771
# 13  1967  Americas   45.032  2586.886053
# 14  1967      Asia   34.020   836.197138

# %%
#Getting unique values
group3 = df.groupby('continent')['country'].nunique()
group3
# Out:
# continent
# Africa      1
# Americas    1
# Asia        1
# Europe      1
# Name: country, dtype: int64

# %%
group4 = df.groupby('year')['lifeExp'].mean()
group4
# Out:
# year
# 1952    41.905500
# 1957    44.296750
# 1962    47.137000
# 1967    49.169750
# 1972    51.252500
# 1977    53.851250
# 1982    54.711000
# 1987    56.691000
# 1992    57.737333
# 1997    58.921000
# 2002    60.554333
# 2007    61.935000
# Name: lifeExp, dtype: float64

# %%
group4.plot()
# Out:
# <AxesSubplot: xlabel='year'>

# %% [markdown]
# The above diagram shows that life expectancy increases with the increase in years
